# %% [markdown]
# ### Import necessary libraries

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## import Data

# %%
bank_det = pd.read_csv('bank-full.csv',sep =';' )

# %%
bank_det
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %% [markdown]
# ### Data understanding

# %%
bank_det.isna().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
bank_det.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
bank_det.head(30)
# Out:
#     age           job   marital  education default  balance housing loan  \
# 0    58    management   married   tertiary      no     2143     yes   no
# 1    44    technician    single  secondary      no       29     yes   no
# 2    33  entrepreneur   married  secondary      no        2     yes  yes
# 3    47   blue-collar   married    unknown      no     1506     yes   no
# 4    33       unknown    single    unknown      no        1      no   no
# 5    35    management   married   tertiary      no      231     yes   no
# 6    28    management    single   tertiary      no      447     yes  yes
# 7    42  entrepreneur  divorced   tertiary     yes        2     yes   no
# 8    58       retired   married    primary      no      121     yes   no
# 9    43    technician    single  secondary      no      593     yes   no
# 10   41        admin.  divorced  secondary      no      270     yes   no
# 11   29        admin.    single  secondary      no      390     yes   no
# ...

# %%
bank_det.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %% [markdown]
# ### Data Preparation

# %%
bank_det = bank_det.drop(columns = ['job','marital','month','education','default','housing','contact','poutcome'])

# %%
bank_det.dtypes
# Out:
# age          int64
# balance      int64
# loan        object
# day          int64
# duration     int64
# campaign     int64
# pdays        int64
# previous     int64
# y           object
# dtype: object

# %%
bank_det.dtypes
# Out:
# age          int64
# balance      int64
# loan        object
# day          int64
# duration     int64
# campaign     int64
# pdays        int64
# previous     int64
# y           object
# dtype: object

# %%
bank_det
# Out:
#        age  balance loan  day  duration  campaign  pdays  previous    y
# 0       58     2143   no    5       261         1     -1         0   no
# 1       44       29   no    5       151         1     -1         0   no
# 2       33        2  yes    5        76         1     -1         0   no
# 3       47     1506   no    5        92         1     -1         0   no
# 4       33        1   no    5       198         1     -1         0   no
# ...    ...      ...  ...  ...       ...       ...    ...       ...  ...
# 45206   51      825   no   17       977         3     -1         0  yes
# 45207   71     1729   no   17       456         2     -1         0  yes
# 45208   72     5715   no   17      1127         5    184         3  yes
# 45209   57      668   no   17       508         4     -1         0   no
# 45210   37     2971   no   17       361         2    188        11   no
#
# [45211 rows x 9 columns]

# %%
bank_det['loan'] = np.where(bank_det['loan'].str.contains("yes"), 1, 0)
bank_det['y'] = np.where(bank_det['y'].str.contains("yes"), 1, 0)

# %%
bank_det
# Out:
#        age  balance  loan  day  duration  campaign  pdays  previous  y
# 0       58     2143     0    5       261         1     -1         0  0
# 1       44       29     0    5       151         1     -1         0  0
# 2       33        2     1    5        76         1     -1         0  0
# 3       47     1506     0    5        92         1     -1         0  0
# 4       33        1     0    5       198         1     -1         0  0
# ...    ...      ...   ...  ...       ...       ...    ...       ... ..
# 45206   51      825     0   17       977         3     -1         0  1
# 45207   71     1729     0   17       456         2     -1         0  1
# 45208   72     5715     0   17      1127         5    184         3  1
# 45209   57      668     0   17       508         4     -1         0  0
# 45210   37     2971     0   17       361         2    188        11  0
#
# [45211 rows x 9 columns]

# %%
X = bank_det.drop(columns = 'y')
y= bank_det[['y']]

# %%
X
# Out:
#        age  balance  loan  day  duration  campaign  pdays  previous
# 0       58     2143     0    5       261         1     -1         0
# 1       44       29     0    5       151         1     -1         0
# 2       33        2     1    5        76         1     -1         0
# 3       47     1506     0    5        92         1     -1         0
# 4       33        1     0    5       198         1     -1         0
# ...    ...      ...   ...  ...       ...       ...    ...       ...
# 45206   51      825     0   17       977         3     -1         0
# 45207   71     1729     0   17       456         2     -1         0
# 45208   72     5715     0   17      1127         5    184         3
# 45209   57      668     0   17       508         4     -1         0
# 45210   37     2971     0   17       361         2    188        11
#
# [45211 rows x 8 columns]

# %%
y
# Out:
#        y
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
# ...   ..
# 45206  1
# 45207  1
# 45208  1
# 45209  0
# 45210  0
#
# [45211 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size =0.20,random_state= None,shuffle= True)

# %%
X_train
# Out:
#        age  balance  loan  day  duration  campaign  pdays  previous
# 22816   32      776     0   25       361         8     -1         0
# 37235   37     2610     0   13        53         1     -1         0
# 20576   55      134     0   12      1650        16     -1         0
# 7520    43     -715     0   30        67         3     -1         0
# 27933   29     1502     0   28        59         1     -1         0
# ...    ...      ...   ...  ...       ...       ...    ...       ...
# 29019   39      186     0    2       171         1     -1         0
# 23175   55       56     0   27        94         6     -1         0
# 2175    29      -72     0   12       208         1     -1         0
# 31232   30      523     1    3        83         1     -1         0
# 43961   57     3287     0   22       867         1     84         3
#
# [36168 rows x 8 columns]

# %%
X_train.shape,y_train.shape
# Out:
# ((36168, 8), (36168, 1))

# %%
X_test.shape,y_test.shape
# Out:
# ((9043, 8), (9043, 1))

# %%
y_train
# Out:
#        y
# 22816  0
# 37235  0
# 20576  0
# 7520   0
# 27933  0
# ...   ..
# 29019  0
# 23175  0
# 2175   0
# 31232  1
# 43961  1
#
# [36168 rows x 1 columns]

# %% [markdown]
# ## Model Training

# %%
from sklearn.linear_model import LogisticRegression
log_model = LogisticRegression()
log_model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
log_model.coef_
# Out:
# array([[-4.89892537e-02,  3.48757929e-05, -3.78966666e-02,
#         -3.67395222e-02,  3.18934208e-03, -2.61836581e-01,
#          9.18039195e-04,  1.00013263e-01]])

# %%
log_model.intercept_
# Out:
# array([-0.06386854])

# %% [markdown]
# ## Model Testing || Model Evaluation

# %% [markdown]
# ###  Training data

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
print(accuracy_score(y_train,y_pred_train))
# Out:
# 0.8874972351249724

# %%
print('Classification Report:\n',classification_report(y_train,y_pred_train))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94     31964
#            1       0.56      0.16      0.25      4204
#
#     accuracy                           0.89     36168
#    macro avg       0.73      0.57      0.59     36168
# weighted avg       0.86      0.89      0.86     36168

# %%
print('confusion Matrix:\n', confusion_matrix(y_train,y_pred_train))
# Out:
# confusion Matrix:
#  [[31431   533]
#  [ 3536   668]]

# %%
from sklearn.metrics import roc_curve,roc_auc_score
fpr,tpr,thresholds =roc_curve(y,log_model.predict_proba (X)[:,1])
auc  = roc_auc_score(y_train,y_pred_train)
print(auc)
import matplotlib.pyplot as plt
plt.plot(fpr,tpr,color ='red',label ='logit model(area =%0.2f)'%auc)
plt.plot([0,1],[0,1],'k--')
plt.xlabel('False Positive Rate or[1- True Negative Rate]')
plt.ylabel('Ture Positive Rate')
# Out:
# 0.5711106399313881
# Text(0, 0.5, 'Ture Positive Rate')

# %%
y_pred_train = log_model.predict(X_train)

# %%
accuracy_score(y_train,y_pred_train)
# Out:
# 0.8874972351249724

# %% [markdown]
# ### Test_data

# %%
print('Classification Report:\n',classification_report(y_test,y_pred_test))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94      7958
#            1       0.56      0.16      0.25      1085
#
#     accuracy                           0.88      9043
#    macro avg       0.73      0.57      0.59      9043
# weighted avg       0.86      0.88      0.85      9043

# %%
('confusion Matrix:\n', confusion_matrix(y_test,y_pred_test))
# Out:
# ('confusion Matrix:\n',
#  array([[7825,  133],
#         [ 914,  171]], dtype=int64))

# %%
y_pred_test = log_model.predict(X_test)

# %%
accuracy_score(y_test,y_pred_test)
# Out:
# 0.8842198385491541

# %%
from sklearn.metrics import roc_curve,roc_auc_score
fpr,tpr,thresholds =roc_curve(y,log_model.predict_proba (X)[:,1])
auc  = roc_auc_score(y_test,y_pred_test)
print(auc)
import matplotlib.pyplot as plt
plt.plot(fpr,tpr,color ='red',label ='logit model(area =%0.2f)'%auc)
plt.plot([0,1],[0,1],'k--')
plt.xlabel('False Positive Rate or[1- True Negative Rate]')
plt.ylabel('Ture Positive Rate')
# Out:
# 0.5704454723704981
# Text(0, 0.5, 'Ture Positive Rate')

# %% [markdown]
# ### optimizing with decision tree model

# %%
from sklearn.tree import DecisionTreeClassifier
dt_model = DecisionTreeClassifier()
dt_model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ### train data

# %%
y_pred_train = dt_model.predict(X_train)
print(accuracy_score(y_train,y_pred_train))
# Out:
# 1.0

# %%
print('Classification Report:\n',classification_report(y_train,y_pred_train))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     31964
#            1       1.00      1.00      1.00      4204
#
#     accuracy                           1.00     36168
#    macro avg       1.00      1.00      1.00     36168
# weighted avg       1.00      1.00      1.00     36168

# %%
print('confusion Matrix:\n', confusion_matrix(y_train,y_pred_train))
# Out:
# confusion Matrix:
#  [[31964     0]
#  [    0  4204]]

# %%
from sklearn.metrics import roc_curve,roc_auc_score
fpr,tpr,thresholds =roc_curve(y,dt_model.predict_proba (X)[:,1])
auc  = roc_auc_score(y_train,y_pred_train)
print(auc)
import matplotlib.pyplot as plt
plt.plot(fpr,tpr,color ='red',label ='logit model(area =%0.2f)'%auc)
plt.plot([0,1],[0,1],'k--')
plt.xlabel('False Positive Rate or[1- True Negative Rate]')
plt.ylabel('Ture Positive Rate')
# Out:
# 1.0
# Text(0, 0.5, 'Ture Positive Rate')

# %% [markdown]
# ### test_data

# %%
y_pred_test = dt_model.predict(X_test)
print(accuracy_score(y_test,y_pred_test))
# Out:
# 0.846953444653323

# %%
print('Classification Report:\n',classification_report(y_test,y_pred_test))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.91      0.91      7958
#            1       0.37      0.41      0.39      1085
#
#     accuracy                           0.85      9043
#    macro avg       0.65      0.66      0.65      9043
# weighted avg       0.85      0.85      0.85      9043

# %%
print('confusion Matrix:\n', confusion_matrix(y_test,y_pred_test))
# Out:
# confusion Matrix:
#  [[7216  742]
#  [ 642  443]]

# %%
from sklearn.metrics import roc_curve,roc_auc_score
fpr,tpr,thresholds =roc_curve(y,dt_model.predict_proba (X)[:,1])
auc  = roc_auc_score(y_test,y_pred_test)
print(auc)
import matplotlib.pyplot as plt
plt.plot(fpr,tpr,color ='red',label ='logit model(area =%0.2f)'%auc)
plt.plot([0,1],[0,1],'k--')
plt.xlabel('False Positive Rate or[1- True Negative Rate]')
plt.ylabel('Ture Positive Rate')
# Out:
# 0.6575277117308265
# Text(0, 0.5, 'Ture Positive Rate')

# %% [markdown]
# #### Model deployement

# %%
from pickle import dump

# %%
dump(log_model,open('log_model.pkl','wb'))

# %%
from pickle import load

# %%
loaded_log_model = load(open('log_model.pkl','rb'))

# %%
y_pred_validation =loaded_log_model.predict(X_test)

# %%
y_pred_validation
# Out:
# array([0, 0, 1, ..., 0, 0, 0])
